# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import bokeh.io
import bokeh.plotting
import bokeh.mpl

# %matplotlib inline 
# %config InlineBackend.figure_formats = ('png', 'retina')

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="22ae83e3-7138-4c75-b50c-e62f6ca78ea3">Loading BokehJS ...</span>
#     </div>

# %%
print('hello, world.')
# Out:
# hello, world.

# %%
4 + 5
# Out:
# 9

# %%
4 + 5
5 + 6
# Out:
# 11

# %% [markdown]
# I can type text in cells that are in markdown.
# I can *lightly emphasize* what I say.
# I can **strongly emphasize** what I say.
#
# This year's bootcamp class is:
# >1. Hard-working.
#     - 9am-10pm for heaven's sake
# 2. Kind
# 3. Good looking
# 4. Tired

# %% [markdown]
# The equation of the day is $m = m_0 e^ {rt}$.
# $ $ tells it that you're giving it stuff in latec
# _ is subscript, > is superscript
#
# Check out this multiline equation.
# \begin{align}
# \frac{\mathrm{d}m}{\mathrm{d}t} &= rt\\
# m &= m_0 e^{rt}
# \end{align}

# %%
df = pd.read_csv('data/grant_1987.csv', comment='#')

# %%
bl_fortis = df.loc[df['species']=='fortis', 'Beak length, mm']
bd_fortis = df.loc[df['species']=='fortis', 'Beak depth, mm']
bl_scandens = df.loc[df['species']=='scandens', 'Beak length, mm']
bd_scandens = df.loc[df['species']=='scandens', 'Beak depth, mm']

plt.plot(bl_fortis, bd_fortis, marker='.', linestyle='none')
plt.plot(bl_scandens, bd_scandens, marker='.', linestyle='none')

# Make it interactive with Bokeh
bokeh.plotting.show(bokeh.mpl.to_bokeh())
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="cc711c07-f210-4e97-9b7e-1015d87eb88a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#cc711c07-f210-4e97-9b7e-1015d87eb88a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc711c07-f210-4e97-9b7e-1015d87eb88a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc711c07-f210-4e97-9b7e-1015d87eb88a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"74c37014-e522-49ba-87e0-921b2957cdd6":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#4C72B0"},"line_color":{"value":"#4C72B0"},"line_width":{"value":0.0},"size":{"units":"screen","value":7.0},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"501ac9c4-dd63-4f62-8f82-74b76e5a93ac","type":"Circle"},{"attributes":{},"id":"5e123f08-32e2-4351-9fb7-7a8ebfca5ec9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["Series 0","Series 1"],"data":{"Series 0":[9.1,9.14,9.24,9.2,8.83,9.14,9.04,10.56,9.7,9.25,9.5,9.34,9.64,9.04,9.8,9.28,9.5,10.8,9.24,10.24,9.74,9.2,9.95,9.34,9.35,10.1,9.96,9.27,9.4,9.68,10.19,10.0,10.25,11.3,9.83,11.04,10.16,10.74,10.19,9.46,9.5,9.7,10.0,10.05,10.3,10.5,9.94,10.04,10.24,9.2,9.3,10.04,10.34,10.34,10.04,9.86,9.73,9.45,10.0,9.78,9.64,9.8,10.0,10.0,10.8,9.64,10.14,10.24,10.74,10.74,11.14,11.24,9.84,9.86,9.96,10.57,10.0,10.95,9.89,9.99,9.1,9.8,9.85,10.0,10.0,10.0,10.18,10.4,10.9,10.04,10.14,10.24,10.54,9.04,9.24,10.06,10.26,10.2,10.93,10.64,10.74,9.4,9.55,9.8,9.83,10.0,10.0,10.3,10.6,11.5,10.24,10.5,10.84,9.94,10.36,9.8,10.09,9.8,9.9,10.0,10.0,10.0,10
.25,11.96,10.0,10.4,10.7,10.7,10.8,10.8,10.85,10.9,11.0,11.1,11.15,11.17,11.2,11.3,11.5,11.7,11.9,12.1,9.14,11.02,11.04,11.24,11.24,11.44,11.44,11.44,11.54,11.54,10.84,10.5,10.86,11.06,11.15,11.26,11.36,12.16,11.6,11.65,10.64,10.2,11.04,11.88,10.3,10.7,10.87,11.0,11.0,11.0,11.13,11.2,11.2,11.3,11.4,11.4,11.04,11.14,11.14,11.24,11.24,11.29,10.34,11.14,11.58,11.84,12.44,10.96,11.46,11.67,10.43,10.73,10.94,11.94,11.1,12.05,10.81,11.29,10.5,10.7,10.9,10.9,11.0,11.0,11.0,11.1,11.2,11.4,11.6,11.7,11.8,11.8,11.9,12.3,11.19,11.24,11.34,11.49,11.64,11.74,11.74,10.94,11.04,11.15,11.3,10.96,11.16,11.26,12.1,10.7,12.3,10.94,11.39,12.01,10.94,11.2,11.34,11.7,11.86,10.8,11.0,11.2,11.3,11.5,11.5,11.7,11.8,11.82,11.9,12.0,11.14,11.74,11.84,12.24,10.95,11.14,11.84,11.84,12.05,12.17,11.04,11.06,11. ...

# %%
df
# Out:
#       band   species  Beak length, mm  Beak depth, mm
# 0    14613    fortis             9.10            7.00
# 1    15487    fortis             9.14            7.12
# 2    15187    fortis             9.24            7.21
# 3    15284    fortis             9.20            7.30
# 4    14983    fortis             8.83            7.32
# 5    14913    fortis             9.14            7.41
# 6    15726    fortis             9.04            7.42
# 7    15821    fortis            10.56            7.43
# 8    15484    fortis             9.70            7.45
# 9     4968    fortis             9.25            7.50
# 10   15695    fortis             9.50            7.50
# 11   15272    fortis             9.34            7.51
# 12   15256    fortis             9.64            7.51
# 13   13907    fortis             9.04            7.64
# 14    5578    fortis             9.80            7.65
# 15   10376    fortis             9.28            7.68
# 16   13377    fortis             9.50            7.70
# 17   15225    fortis            10.80            7.80
# 18   15914    fortis             9.24            7.81
# 19   14760    fortis            10.24            7.81
# 20   15779    fortis             9.74            7.86
# 21   13901    fortis             9.20            7.90
# 22   15277    fortis             9.95            7.90
# 23   15285    fortis             9.34            7.92
# 24   13194    fortis             9.35            7.92
# 25   14967    fortis            10.10            7.92
# 26   14800    fortis             9.96            7.93
# 27   14612    fortis             9.27            7.95
# 28   15154    fortis             9.40            7.95
# 29   14123    fortis             9.68            7.96
# ..     ...       ...              ...             ...
# 913  15694  scandens            13.14            9.51
# 914  15421  scandens            14.44            9.51
# 915  14208  scandens            12.73            9.52
# 916   1396  scandens            15.04            9.54
# 917   1444  scandens            14.85            9.55
# 918   4051  scandens            14.20            9.60
# 919  10061  scandens            15.20            9.60
# 920   4701  scandens            16.00            9.60
# 921  13257  scandens            14.47            9.62
# 922   2949  scandens            14.54            9.64
# 923  14946  scandens            14.90            9.65
# 924   5656  scandens            14.90            9.70
# 925   5608  scandens            15.80            9.70
# 926  15352  scandens            13.46            9.73
# 927  15817  scandens            14.77            9.73
# 928   4119  scandens            14.44            9.74
# 929  10223  scandens            15.20            9.80
# 930   2969  scandens            16.00            9.80
# 931  14648  scandens            14.40            9.82
# 932  15658  scandens            14.45            9.85
# 933  13256  scandens            15.35            9.85
# 934   8425  scandens            14.20            9.90
# 935  14524  scandens            15.30            9.90
# 936  10075  scandens            14.27            9.94
# 937   4137  scandens            15.80           10.00
# 938  14847  scandens            15.30           10.10
# 939  15886  scandens            11.24           10.11
# 940  14877  scandens            15.20           10.27
# 941   8036  scandens            15.44           10.34
# 942  14579  scandens            14.96           11.33
#
# [943 rows x 4 columns]

# %%
p = bokeh.plotting.figure(height=400, width=500, x_axis_label='beak length (mm)', y_axis_label='beak depth (mm')

p.circle(bl_fortis, bd_fortis, color='dodgerblue', alpha=0.5, legend='fortis')
p.circle(bl_scandens, bd_scandens, color='tomato', alpha=0.5, legend='scandens')

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="75f76434-e10d-4ec0-b9d9-447d9ff3a864"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#75f76434-e10d-4ec0-b9d9-447d9ff3a864").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75f76434-e10d-4ec0-b9d9-447d9ff3a864");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75f76434-e10d-4ec0-b9d9-447d9ff3a864' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e37c280d-38ee-4a4d-bb87-ea65a6a6dd7a":{"roots":{"references":[{"attributes":{"data_source":{"id":"815d91c4-86d6-4596-ad1f-ee2a4e1c4bd2","type":"ColumnDataSource"},"glyph":{"id":"870be32d-82dd-4265-b403-27265556c738","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"546d2074-9b0f-4621-8f8d-8174f7d578fa","type":"Circle"},"selection_glyph":null},"id":"1578847a-0927-4cd4-8353-ed409e5bfe82","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fc5211a0-16bf-47a8-b6e2-0ce355862ae6","subtype":"Figure","type":"Plot"}},"id":"f46b51c0-c67a-40be-ade1-dc79d825da4e","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"tomato"},"line_alpha":{"value":0.5},"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a8bcb47b-9310-4d9e-88fe-41299cf0afc0","type":"Circle"},{"attributes":{"plot":{"id":"fc5211a0-16bf-47a8-b6e2-0ce355862ae6","subtype":"Figure","type":"Plot"}},"id":"445fb4ca-ff6f-42cf-9a26-59caf99dc883","type":"HelpTool"},{"attributes":{},"id":"9fdcac04-5b2a-43ca-a67e-330babccd966","type":"ToolEvents"},{"attributes":{"plot":{"id":"fc5211a0-16bf-47a8-b6e2-0ce355862ae6","subtype":"Figure","type":"Plot"},"ticker":{"id":"cd379026-39ac-4715-a1c7-3e6c235acd5a","type":"BasicTicker"}},"id":"01ded051-e951-482a-8e09-f4024caa757e","type":"Grid"},{"attributes":{"plot":null,"text":null},"id":"f3ddde5c-7cfc-48f6-994a-761eb9f573b4","type":"Title"},{"attributes":{"plot":{"id":"fc5211a0-16bf-47a8-b6e2-0ce355862ae6","subtype":"Figure","type":"Plot"}},"id":"6c9ca845-c65d-4862-a3e3-7952be253180","type":"SaveTool"},{"attributes":{},"id":"a68a2c46-9910-491d-8a93-7ffc22f1e110","type":"BasicTicker"},{"attributes":{"callback":null},"id":"8b784efc-a180-46ff-9c8e-d4e36d0f9fe3","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"